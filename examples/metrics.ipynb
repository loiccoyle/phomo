# %%
from phomo import Mosaic, Master, Pool

# %% [markdown]
# Create the tile pool

# %%
pool = Pool.from_dir("faces/", crop_ratio=1, tile_size=(20, 20))
# Out:
# Loading tiles:   0%|          | 0/9780 [00:00<?, ?it/s]

# %% [markdown]
# Get a random image for the master image.

# %%
from random import sample
from pathlib import Path

master_file = sample(list(Path("faces").glob('*')), 1)[0]

# %%
master = Master.from_file(master_file, img_size=(400, 400))
master.img
# Out:
# <PIL.Image.Image image mode=RGB size=400x400 at 0x7FD328563580>

# %%
mosaic = Mosaic(master, pool)

# %% [markdown]
# ## All the different metrics

# %%
mosaic.build(metric="norm")
# Out:
# Building distance matrix:   0%|          | 0/400 [00:00<?, ?it/s]
# Building mosaic:   0%|          | 0/400 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=400x400 at 0x7FD3285DC850>

# %%
mosaic.build(metric="greyscale")
# Out:
# Building distance matrix:   0%|          | 0/400 [00:00<?, ?it/s]
# Building mosaic:   0%|          | 0/400 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=400x400 at 0x7FD3285C5A30>

# %%
mosaic.build(metric="luv_approx")
# Out:
# Building distance matrix:   0%|          | 0/400 [00:00<?, ?it/s]
# Building mosaic:   0%|          | 0/400 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=400x400 at 0x7FD3285ADDF0>

# %% [markdown]
# ## Changing the parameters of `np.linalg.norm`
#
# This results in slightly different mosaics.
#
# See the numpy docs:
# https://numpy.org/doc/stable/reference/generated/numpy.linalg.norm.html

# %%
mosaic.build(metric="norm", ord=1)
# Out:
# Building distance matrix:   0%|          | 0/400 [00:00<?, ?it/s]
# Building mosaic:   0%|          | 0/400 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=400x400 at 0x7FD326B6C880>

# %%
mosaic.build(metric="norm", ord=2)
# Out:
# Building distance matrix:   0%|          | 0/400 [00:00<?, ?it/s]
# Building mosaic:   0%|          | 0/400 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=400x400 at 0x7FD3285DCB20>

# %%
mosaic.build(metric="norm", ord="fro")
# Out:
# Building distance matrix:   0%|          | 0/400 [00:00<?, ?it/s]
# Building mosaic:   0%|          | 0/400 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=400x400 at 0x7FD326B96A90>

# %%
mosaic.build(metric="norm", ord="nuc")
# Out:
# Building distance matrix:   0%|          | 0/400 [00:00<?, ?it/s]
# Building mosaic:   0%|          | 0/400 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=400x400 at 0x7FD3278E5EE0>
